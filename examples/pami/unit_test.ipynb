# %%
import os 
print(os.getcwd())
# Out:
# C:\Users\Chi Huynh\Documents\NTGenerator\toy problem\examples\pami

# %%
pip install torch
# Out:
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ---------------------------------------- 0.0/241.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/241.3 MB 1.9 MB/s eta 0:02:06
#    ---------------------------------------- 0.2/241.3 MB 2.1 MB/s eta 0:01:55
#    ---------------------------------------- 0.2/241.3 MB 1.8 MB/s eta 0:02:14
#    ---------------------------------------- 0.3/241.3 MB 1.7 MB/s eta 0:02:25
#    ---------------------------------------- 0.3/241.3 MB 1.5 MB/s eta 0:02:37
#    ---------------------------------------- 0.4/241.3 MB 1.5 MB/s eta 0:02:45
#    ---------------------------------------- 0.5/241.3 MB 1.5 MB/s eta 0:02:41
#    ---------------------------------------- 0.6/241.3 MB 1.5 MB/s eta 0:02:37
#    ---------------------------------------- 0.7/241.3 MB 1.6 MB/s eta 0:02:28
# ...

# %%
from stage_based import Toy2DDataset
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from stage_based import Toy2DDataset
#
# File ~\Documents\NTGenerator\toy problem\examples\pami\stage_based.py:3
#       1 # -*- coding: utf-8 -*-
#       2 # Canonical Nuisance Pipeline (PyTorch, 2D toy) — teachers → signal-max pretrain → prototype-canonical finetune
# ----> 3 import math, copy, torch, torch.nn as nn, torch.nn.functional as F
#       4 from torch.utils.data import Dataset, DataLoader
#       5 torch.manual_seed(42)
#
# ModuleNotFoundError: No module named 'torch'
